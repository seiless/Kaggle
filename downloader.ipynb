# %%
from programs.utils import kaggle_download

# %%
kaggle_download.download_and_extract_kaggle_competition("jigsaw-agile-community-rules")
# Out:
# Attempting to extract files...
# Extraction complete. Files are saved in: './jigsaw-agile-community-rules\data'
